# %% [markdown]
# # Creating Process Flows
#
# The below image shows two process flows created inside a single project in SAS EG. For Lesson 1 a sample SAS dataset containing airline data is imported and 'describe' task is used to characterize the data to create a summary report, graphs and frequency and univariate SAS data set to descibe the main characteristics of data.
#
# ![image.png](attachment:image.png)
